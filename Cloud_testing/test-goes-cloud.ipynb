# %%
import xarray as xr
import s3fs
#file = 'c:/Users/gentemann/Downloads/OR_ABI-L2-SSTF-M6_G16_s20202130100189_e20202130159497_c20202130205354.nc'
#ds = xr.open_dataset(file)
ds
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-e21fe3f47a5e> in <module>
#       1 import xarray as xr
# ----> 2 import s3fs
#       3 #file = 'c:/Users/gentemann/Downloads/OR_ABI-L2-SSTF-M6_G16_s20202130100189_e20202130159497_c20202130205354.nc'
#       4 #ds = xr.open_dataset(file)
#       5 #ds
#
# ModuleNotFoundError: No module named 's3fs'

# %%
fs = s3fs.S3FileSystem(anon=True)
#file_location = fs.ls('s3:/noaa-himawari8/AHI-L2-FLDK-SST/2020/04/01/0000/')
file_location = fs.ls('s3://noaa-goes16/ABI-L2-SSTF/2020/213/01/')
file_ob = fs.open(file_location[0])
ds = xr.open_dataset(file_ob)
ds
#file = 's3://noaa-goes16/ABI-L2-SSTF/2020/213/01/OR_ABI-L2-SSTF-M6_G16_s20202130100189_e20202130159497_c20202130205354.nc'
#ds = xr.open_dataset(file)
#ds
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-70a0b5c970f8> in <module>
# ----> 1 fs = s3fs.S3FileSystem(anon=True)
#       2 #file_location = fs.ls('s3:/noaa-himawari8/AHI-L2-FLDK-SST/2020/04/01/0000/')
#       3 file_location = fs.ls('s3://noaa-goes16/ABI-L2-SSTF/2020/213/01/')
#       4 file_ob = fs.open(file_location[0])
#       5 ds = xr.open_dataset(file_ob)
#
# NameError: name 's3fs' is not defined

# %%
import requests
