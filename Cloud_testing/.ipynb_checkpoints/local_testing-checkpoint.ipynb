# %%
import warnings
import xarray as xr
import fsspec
import s3fs

# %%
file_location = 's3://goes-zarr/goes210.zarr'
ds_sst = xr.open_zarr(fsspec.get_mapper(file_location, anon=True),consolidated=True)
#ds_sst = xr.open_zarr('f:/goes210.zarr')
ds_sst
# Out:
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-3-333c8286d480> in <module>
#       1 file_location = 's3://goes-zarr/goes210.zarr'
# ----> 2 ds_sst = xr.open_zarr(fsspec.get_mapper(file_location),consolidated=True)
#       3 #ds_sst = xr.open_zarr('f:/goes210.zarr')
#       4 ds_sst
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\xarray\backends\zarr.py in open_zarr(store, group, synchronizer, chunks, decode_cf, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, consolidated, overwrite_encoded_chunks, decode_timedelta, **kwargs)
#     639     # reads or writes from a store, never both. For open_zarr, we only read
#     640     mode = "r"
# --> 641     zarr_store = ZarrStore.open_group(
#     642         store,
#     643         mode=mode,
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\xarray\backends\zarr.py in open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close)
#     283         if consolidated:
#     284             # TODO: an option to pass the metadata_key keyword
# --> 285             zarr_group = zarr.open_consolidated(store, **open_kwargs)
#     286         else:
#     287             zarr_group = zarr.open_group(store, **open_kwargs)
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\zarr\convenience.py in open_consolidated(store, metadata_key, mode, **kwargs)
#    1177
#    1178     # setup metadata sotre
# -> 1179     meta_store = ConsolidatedMetadataStore(store, metadata_key=metadata_key)
#    1180
#    1181     # pass through
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\zarr\storage.py in __init__(self, store, metadata_key)
#    2499
#    2500         # retrieve consolidated metadata
# -> 2501         meta = json_loads(store[metadata_key])
#    2502
#    2503         # check format of consolidated metadata
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\fsspec\mapping.py in __getitem__(self, key, default)
#      73         k = self._key_to_str(key)
#      74         try:
# ---> 75             result = self.fs.cat(k)
#      76         except (FileNotFoundError, IsADirectoryError, NotADirectoryError):
#      77             if default is not None:
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\fsspec\spec.py in cat(self, path)
#     585     def cat(self, path):
#     586         """ Get the content of a file """
# --> 587         return self.open(path, "rb").read()
#     588
#     589     def get(self, rpath, lpath, recursive=False, **kwargs):
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\fsspec\spec.py in open(self, path, mode, block_size, cache_options, **kwargs)
#     767         else:
#     768             ac = kwargs.pop("autocommit", not self._intrans)
# --> 769             f = self._open(
#     770                 path,
#     771                 mode=mode,
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\s3fs\core.py in _open(self, path, mode, block_size, acl, version_id, fill_cache, cache_type, autocommit, requester_pays, **kwargs)
#     373             cache_type = self.default_cache_type
#     374
# --> 375         return S3File(self, path, mode, block_size=block_size, acl=acl,
#     376                       version_id=version_id, fill_cache=fill_cache,
#     377                       s3_additional_kwargs=kw, cache_type=cache_type,
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\s3fs\core.py in __init__(self, s3, path, mode, block_size, acl, version_id, fill_cache, s3_additional_kwargs, autocommit, cache_type, requester_pays)
#    1094         self.s3_additional_kwargs = s3_additional_kwargs or {}
#    1095         self.req_kw = {'RequestPayer': 'requester'} if requester_pays else {}
# -> 1096         super().__init__(s3, path, mode, block_size, autocommit=autocommit,
#    1097                          cache_type=cache_type)
#    1098         self.s3 = self.fs  # compatibility
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\fsspec\spec.py in __init__(self, fs, path, mode, block_size, autocommit, cache_type, cache_options, **kwargs)
#    1063         if mode == "rb":
#    1064             if not hasattr(self, "details"):
# -> 1065                 self.details = fs.info(path)
#    1066             self.size = self.details["size"]
#    1067             self.cache = caches[cache_type](
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\s3fs\core.py in info(self, path, version_id, refresh)
#     527         if self.version_aware or (key and self._ls_from_cache(path) is None) or refresh:
#     528             try:
# --> 529                 out = self._call_s3(self.s3.head_object, kwargs, Bucket=bucket,
#     530                                     Key=key, **version_id_kw(version_id), **self.req_kw)
#     531                 return {
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\s3fs\core.py in _call_s3(self, method, *akwarglist, **kwargs)
#     198         additional_kwargs = self._get_s3_method_kwargs(method, *akwarglist,
#     199                                                        **kwargs)
# --> 200         return method(**additional_kwargs)
#     201
#     202     def _get_s3_method_kwargs(self, method, *akwarglist, **kwargs):
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
#     318         _api_call.__name__ = str(py_operation_name)
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     619             http, parsed_response = event_response
#     620         else:
# --> 621             http, parsed_response = self._make_request(
#     622                 operation_model, request_dict, request_context)
#     623
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\client.py in _make_request(self, operation_model, request_dict, request_context)
#     639     def _make_request(self, operation_model, request_dict, request_context):
#     640         try:
# --> 641             return self._endpoint.make_request(operation_model, request_dict)
#     642         except Exception as e:
#     643             self.meta.events.emit(
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\endpoint.py in make_request(self, operation_model, request_dict)
#     100         logger.debug("Making request for %s with params: %s",
#     101                      operation_model, request_dict)
# --> 102         return self._send_request(request_dict, operation_model)
#     103
#     104     def create_request(self, params, operation_model=None):
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\endpoint.py in _send_request(self, request_dict, operation_model)
#     130     def _send_request(self, request_dict, operation_model):
#     131         attempts = 1
# --> 132         request = self.create_request(request_dict, operation_model)
#     133         context = request_dict['context']
#     134         success_response, exception = self._get_response(
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\endpoint.py in create_request(self, params, operation_model)
#     113                 service_id=service_id,
#     114                 op_name=operation_model.name)
# --> 115             self._event_emitter.emit(event_name, request=request,
#     116                                      operation_name=operation_model.name)
#     117         prepared_request = self.prepare_request(request)
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\hooks.py in emit(self, event_name, **kwargs)
#     354     def emit(self, event_name, **kwargs):
#     355         aliased_event_name = self._alias_event_name(event_name)
# --> 356         return self._emitter.emit(aliased_event_name, **kwargs)
#     357
#     358     def emit_until_response(self, event_name, **kwargs):
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\hooks.py in emit(self, event_name, **kwargs)
#     226                  handlers.
#     227         """
# --> 228         return self._emit(event_name, kwargs)
#     229
#     230     def emit_until_response(self, event_name, **kwargs):
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\hooks.py in _emit(self, event_name, kwargs, stop_on_response)
#     209         for handler in handlers_to_call:
#     210             logger.debug('Event %s: calling handler %s', event_name, handler)
# --> 211             response = handler(**kwargs)
#     212             responses.append((handler, response))
#     213             if stop_on_response and response is not None:
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\signers.py in handler(self, operation_name, request, **kwargs)
#      88         # this method is invoked to sign the request.
#      89         # Don't call this method directly.
# ---> 90         return self.sign(operation_name, request)
#      91
#      92     def sign(self, operation_name, request, region_name=None,
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\signers.py in sign(self, operation_name, request, region_name, signing_type, expires_in, signing_name)
#     158                     raise e
#     159
# --> 160             auth.add_auth(request)
#     161
#     162     def _choose_signer(self, operation_name, signing_type, context):
#
# ~\Miniconda3\envs\satenv2\lib\site-packages\botocore\auth.py in add_auth(self, request)
#     355     def add_auth(self, request):
#     356         if self.credentials is None:
# --> 357             raise NoCredentialsError
#     358         datetime_now = datetime.datetime.utcnow()
#     359         request.context['timestamp'] = datetime_now.strftime(SIGV4_TIMESTAMP)
#
# NoCredentialsError: Unable to locate credentials

# %%
file_location = 's3://mur-sst/zarr'
dssst = xr.open_zarr(fsspec.get_mapper(file_location, anon=True),consolidated=True)
ds_sst

# %%
sst=ds_sst.sel(time='2015-10-10T09').load()

# %%
(sst.analysed_sst-273.15).plot(vmin=0,vmax=32,cmap='jet')

# %%
sst_timeseries = ds_sst.sel(lon=-140, lat=53).load()
