# %% [markdown]
# # Jupyter Notebooks
# ![jupyter_logo.png](attachment:jupyter_logo.png)
#
# Jupyter is a project for developing open-source software
# Jupyter Notebooks is a web application to create programming scripts
#
# But it is more than that. It also let you insert text, equations and visualizations ... in a single page.
#
#
# we will jsut cover the basics to work here, but you can find links to tutorial at the end

# %% [markdown]
# ## But it is more than that. It also let you insert text, equations and visualizations ... in a single page.
# ![jupyternotebook_imageexample.png](attachment:jupyternotebook_imageexample.png)

# %%
header: file name, type of cels
describe parts: cells, type of cells, and command icons and menus - kernel 
and commands
(image of header)

# %% [markdown]
# This might or not be necessary:
# jupyter file list (home page?)
# How to start a new program - language, name, save in it.

# %%
running a program 
basic - cell running (shift enter)
enter - edit a cell
command s - save changes

commands menu
- moving between cells, add cell, move, save, type of cell, run cell

# %%
edit mode (by cell)
command mode (entire file/script)

# %%
basic keyboard comands
same ones 
and image (help keyboard shortcuts)

# %%
give some links to longer tutorials and help
Main website: https://jupyter.org/
