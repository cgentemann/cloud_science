# %% [markdown]
# <div align='right'><img src='images/sst_avhrroi.png'></div>
#
# # Python for Oceanographers
# Chelle Gentemann (cgentemann@esr.org)
#
# Marisol García-Reyes (marisolgr@faralloninstitute.org)
#
# ### Please go to:
# https://github.com/cgentemann/cloud_science/tree/master/GHRSST_tutorial
# ### Scroll down & click on the launch button:
# <div align='center'><img src='images/bynder-icon.png' border="5"></div>

# %% [markdown]
# # Introduction to
#
#
# ![python-logo.png](attachment:python-logo.png)

# %% [markdown]
# ## `Python` is an awesome programming language
# - Runs anywhere and it is free
# - It was created in 1991
# - Note: we will be using version `Python` 3.x or 3.7.x
# - Interactive
# - Multiple data types

# %% [markdown]
# Another big advantage is that new (& useful) packages can be (& are) added by a large & increasing community of users, keeping it up to date with user's needs

# %% [markdown]
# ![trends_stackoverflow.png](attachment:trends_stackoverflow.png)

# %% [markdown]
# ## Python's Scientific Ecosystem
# Thanks to its block building capability, Python has become a whole (eco)system with amazing capabilities.

# %% [markdown]
# ![scipy_ecosystem.png](attachment:scipy_ecosystem.png)

# %% [markdown]
# ## Why is this good?
# - Because you only need to install and initialize the packages / libraries you need to run your code, making things lighter
# - Being community-developed, packages/libraries are developed by the same communities that use them and need them... this is, custom made

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr

# %% [markdown]
# ## Different paths to use `Python`
# ![install_run_python.png](attachment:install_run_python.png)

# %% [markdown]
# ### Before we start properly with python, a word about finding help
#
# As `Python` has a big community of developers & users, it is easy to find help online
# - First ask `google`. It will either send you to examples, the reference or tutorials.
# - But eventually it will send you to ... stack<b>overflow</b>

# %% [markdown]
# ![stackoverflow_screenshot.png](attachment:stackoverflow_screenshot.png)

# %% [markdown]
# ## And now, if your `Jupyter notebook bynders` are loaded
# ## Let's start!
# # By the way, you're already working in the cloud!!!
